# %% [markdown]
# <a href="https://colab.research.google.com/github/RoxPiceno/BD-No-SpL/blob/main/Pr%C3%A1ctica3_JSON_NoSqL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

json_text = '''
 {
	"Musica": {
		"Genero": [
			{
				"Nombre": "Jazz, soul-jazz, blues / RyB",
				"Artista": "Nina Simone",
				"Ano": "1965 (1 de octubre de 1965)",
				"Album": "Pastel Blues",
				"Duracion": "35:02 minutos",
				"Canciones": "9 pistas"
			},
			{
				"Nombre": "Jazz, soul-jazz, blues / RyB",
				"Artista": "Billie Holiday",
				"Ano": "1958",
				"Album": "Lady in Satin",
				"Duracion": "41:00 minutos",
				"Canciones": "12 pistas, versión original"
			},
			{
				"Nombre": "Gothic metal / rock sinfónico",
				"Artista": "Lacrimosa",
				"Ano": "1999",
				"Album": "Elodia",
				"Duracion": "57:57 minutos",
				"Canciones": "8 pistas"
			}
		]
	}
}
'''
# Convertir JSON → diccionario de Python
data = json.loads(json_text)

# Mostrarlo ya como estructura Python
print(data)

for genero in data["Musica"]["Genero"]:
    print("Nombre del género:", genero["Nombre"])
    print("Artista:", genero["Artista"])
    print("Álbum:", genero["Album"])
    print("Año:", genero["Ano"])
    print("Duración:", genero["Duracion"])
    print("Canciones:", genero["Canciones"])
    print("-" * 40)

    # Convertir JSON a diccionario
data = json.loads(json_text)
# Out:
# {'Musica': {'Genero': [{'Nombre': 'Jazz, soul-jazz, blues / RyB', 'Artista': 'Nina Simone', 'Ano': '1965 (1 de octubre de 1965)', 'Album': 'Pastel Blues', 'Duracion': '35:02 minutos', 'Canciones': '9 pistas'}, {'Nombre': 'Jazz, soul-jazz, blues / RyB', 'Artista': 'Billie Holiday', 'Ano': '1958', 'Album': 'Lady in Satin', 'Duracion': '41:00 minutos', 'Canciones': '12 pistas, versión original'}, {'Nombre': 'Gothic metal / rock sinfónico', 'Artista': 'Lacrimosa', 'Ano': '1999', 'Album': 'Elodia', 'Duracion': '57:57 minutos', 'Canciones': '8 pistas'}]}}
# Nombre del género: Jazz, soul-jazz, blues / RyB
# Artista: Nina Simone
# Álbum: Pastel Blues
# Año: 1965 (1 de octubre de 1965)
# Duración: 35:02 minutos
# Canciones: 9 pistas
# ----------------------------------------
# Nombre del género: Jazz, soul-jazz, blues / RyB
# Artista: Billie Holiday
# Álbum: Lady in Satin
# Año: 1958
# Duración: 41:00 minutos
# Canciones: 12 pistas, versión original
# ----------------------------------------
# ...

# %%
import json

json_text = '''

{
	"Libros": {
		"Clasificacion": [
			{
				"Titulo": "El Principito",
				"Autor": "Saint-Exupéry Antoine",
				"Precio": "$124",
				"FechaIngreso": "15/Noviembre/2025",
				"ISBN": "9789500426404",
				"Inventario": "15 ejemplares",
				"__text": "Novela"
			},
			{
				"Titulo": "Homo Deus",
				"Autor": "Harari Yuval Noah",
				"Precio": "$424",
				"FechaIngreso": "15/Noviembre/2025",
				"ISBN": "9786073821292",
				"Inventario": "20 ejemplares",
				"__text": "Ensayo no ficción"
			},
			{
				"Titulo": "Principios de Economía",
				"Autor": "Mankiw N. Gregory",
				"Precio": "$724",
				"FechaIngreso": "15/Noviembre/2025",
				"ISBN": "9786075269481",
				"Inventario": "25 ejemplares",
				"__text": "Economia"
			}
		]
	}
}
'''
# Convertir JSON → diccionario de Python
data = json.loads(json_text)

# Mostrarlo como estructura Python
print(data)

# Mostrar el diccionario con formato bonito
print(json.dumps(data, indent=4, ensure_ascii=False))
# Out:
# {'Libros': {'Clasificacion': [{'Titulo': 'El Principito', 'Autor': 'Saint-Exupéry Antoine', 'Precio': '$124', 'FechaIngreso': '15/Noviembre/2025', 'ISBN': '9789500426404', 'Inventario': '15 ejemplares', '__text': 'Novela'}, {'Titulo': 'Homo Deus', 'Autor': 'Harari Yuval Noah', 'Precio': '$424', 'FechaIngreso': '15/Noviembre/2025', 'ISBN': '9786073821292', 'Inventario': '20 ejemplares', '__text': 'Ensayo no ficción'}, {'Titulo': 'Principios de Economía', 'Autor': 'Mankiw N. Gregory', 'Precio': '$724', 'FechaIngreso': '15/Noviembre/2025', 'ISBN': '9786075269481', 'Inventario': '25 ejemplares', '__text': 'Economia'}]}}
# {
#     "Libros": {
#         "Clasificacion": [
#             {
#                 "Titulo": "El Principito",
#                 "Autor": "Saint-Exupéry Antoine",
#                 "Precio": "$124",
#                 "FechaIngreso": "15/Noviembre/2025",
#                 "ISBN": "9789500426404",
#                 "Inventario": "15 ejemplares",
# ...
