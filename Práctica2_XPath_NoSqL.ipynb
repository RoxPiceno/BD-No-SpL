# %% [markdown]
# <a href="https://colab.research.google.com/github/RoxPiceno/BD-No-SpL/blob/main/Pr%C3%A1ctica2_XPath_NoSqL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#e.tree es libreria dentro de python para usar arboles de raíz hacia

import xml.etree.ElementTree as ET

# Create a dummy XML file for demonstration
xml_data = '''
<movielist>
    <movie>
        <title>The Shawshank Redemption</title>
        <director>Frank Darabont</director>
        <year>1994</year>
    </movie>
    <movie>
        <title>The Godfather</title>
        <director>Francis Ford Coppola</director>
        <year>1972</year>
    </movie>
    <movie>
        <title>Pulp Fiction</title>
        <director>Quentin Tarantino</director>
        <year>1994</year>
    </movie>
</movielist>
'''
#'w' es para sólo lectura

with open('movielist.xml', 'w') as f:
    f.write(xml_data)

print("Dummy 'movielist.xml' created successfully.")

# Parse the XML file abrir y recorder un archivo
tree = ET.parse('movielist.xml')
root = tree.getroot()

# Iterate and print movie data
print("\nMovie DataBase")
for movie in root.findall("movie"): #desde la raíz encuentra cada hijo
    title = movie.find("title").text
    director = movie.find("director").text
    year = movie.find("year").text
    print(f"Title: {title}, Director: {director}, Year: {year}")
# Out:
# Dummy 'movielist.xml' created successfully.
#
# Movie DataBase
# Title: The Shawshank Redemption, Director: Frank Darabont, Year: 1994
# Title: The Godfather, Director: Francis Ford Coppola, Year: 1972
# Title: Pulp Fiction, Director: Quentin Tarantino, Year: 1994

# %% [markdown]
# **---- Práctica con código XML Peliculas ----**

# %%
import xml.etree.ElementTree as ET

# Create a dummy XML file for demonstration
xml_data = '''

   <peliculas>
       <genero>Novela
         <titulo>Le Fabuleux Destind ́Amélie Poulain</titulo>
         <director>Jean-Pierre Jeunet</director>
         <ano>2001</ano>
         <paisorigen>Francia</paisorigen>
         <premios>2 BAFTA (mejor guión, mejor producción) 5 Nominaciones </premios>
       </genero>

       <genero>Sátira surrealista, terror psicológico, drama
         <titulo>Beau is Afraid</titulo>
         <director>Ari Aster</director>
         <ano>2023</ano>
         <paisorigen>Estados Unidos</paisorigen>
         <premios>Pelicula de culto sin premios hasta ahora</premios>
       </genero>

       <genero>Fantasía romántica, drama surrealista
         <titulo>L'Écume des jour/Amor Índigo</titulo>
         <director>Michael Gondry</director>
         <ano>2013</ano>
         <paisorigen>Francia</paisorigen>
         <premios>Nom a César (mejor producción </premios>
       </genero>

       <genero>Drama romántico
         <titulo>La Vie d'Adele</titulo>
         <director>Abdellatif Kechiche</director>
         <ano>2013</ano>
         <paisorigen>Francia</paisorigen>
         <premios>Palma de oro FestCannes;considerada una de las mejores del cine contemporáneo </premios>
        </genero>
  </peliculas>

'''

#'w' es para sólo lectura

with open('peliculas.xml', 'w') as f:
    f.write(xml_data)

print("Dummy 'peliculas.xml' created successfully.")

# Parse the XML file abrir y recorder un archivo
tree = ET.parse('peliculas.xml')
root = tree.getroot()

# Iterate and print libro data
print("\ngenero DataBase")
for genero in root.findall("genero"): #desde la raíz encuentra cada hijo
    titulo = genero.find("titulo").text
    director = genero.find("director").text
    ano = genero.find("ano").text
    paisorigen = genero.find("paisorigen").text
    premios = genero.find("premios").text
    print(f"titulo: {titulo}, director: {director}, ano: {ano}, paisorigen: {paisorigen}, premios: {premios}")
# Out:
# Dummy 'peliculas.xml' created successfully.
#
# genero DataBase
# titulo: Le Fabuleux Destind ́Amélie Poulain, director: Jean-Pierre Jeunet, ano: 2001, paisorigen: Francia, premios: 2 BAFTA (mejor guión, mejor producción) 5 Nominaciones
# titulo: Beau is Afraid, director: Ari Aster, ano: 2023, paisorigen: Estados Unidos, premios: Pelicula de culto sin premios hasta ahora
# titulo: L'Écume des jour/Amor Índigo, director: Michael Gondry, ano: 2013, paisorigen: Francia, premios: Nom a César (mejor producción
# titulo: La Vie d'Adele, director: Abdellatif Kechiche, ano: 2013, paisorigen: Francia, premios: Palma de oro FestCannes;considerada una de las mejores del cine contemporáneo

# %% [markdown]
# **---- Práctica con código XML libros ----**

# %%
import xml.etree.ElementTree as ET

# Create a dummy XML file for demonstration
xml_data = '''

 <Libros>
     <Clasificacion>Novela
         <Titulo>El Principito</Titulo>
         <Autor>Saint-Exupéry Antoine</Autor>
         <Precio>$124</Precio>
         <FechaIngreso>15/Noviembre/2025</FechaIngreso>
         <ISBN>9789500426404</ISBN>
         <Inventario>15 ejemplares</Inventario>
        </Clasificacion>

      <Clasificacion>Ensayo no ficción
         <Titulo>Homo Deus</Titulo>
         <Autor>Harari Yuval Noah</Autor>
         <Precio>$424</Precio>
         <FechaIngreso>15/Noviembre/2025</FechaIngreso>
         <ISBN>9786073821292</ISBN>
         <Inventario>20 ejemplares</Inventario>
      </Clasificacion>

      <Clasificacion>Economia
         <Titulo>Principios de Economía</Titulo>
         <Autor>Mankiw N. Gregory</Autor>
         <Precio>$724</Precio>
         <FechaIngreso>15/Noviembre/2025</FechaIngreso>
         <ISBN>9786075269481</ISBN>
         <Inventario>25 ejemplares</Inventario>
      </Clasificacion>
  </Libros>
'''

#'w' es para sólo lectura

with open('Libros.xml', 'w') as f:
    f.write(xml_data)

print("Dummy 'Libros.xml' created successfully.")

# Parse the XML file abrir y recorder un archivo
tree = ET.parse('Libros.xml')
root = tree.getroot()

# Iterate and print libro data
print("\nClasificacion DataBase")
for Clasificacion in root.findall("Clasificacion"): #desde la raíz encuentra cada hijo
    Titulo = Clasificacion.find("Titulo").text
    Autor = Clasificacion.find("Autor").text
    Precio = Clasificacion.find("Precio").text
    FechaIngreso = Clasificacion.find("FechaIngreso").text
    ISBN = Clasificacion.find("ISBN").text
    Inventario = Clasificacion.find("Inventario").text
    print(f"Titulo: {Titulo}, Autor: {Autor}, Precio: {Precio}, FechaIngreso: {FechaIngreso}, ISBN: {ISBN}, Inventario: {Inventario}")
# Out:
# Dummy 'Libros.xml' created successfully.
#
# Clasificacion DataBase
# Titulo: El Principito, Autor: Saint-Exupéry Antoine, Precio: $124, FechaIngreso: 15/Noviembre/2025, ISBN: 9789500426404, Inventario: 15 ejemplares
# Titulo: Homo Deus, Autor: Harari Yuval Noah, Precio: $424, FechaIngreso: 15/Noviembre/2025, ISBN: 9786073821292, Inventario: 20 ejemplares
# Titulo: Principios de Economía, Autor: Mankiw N. Gregory, Precio: $724, FechaIngreso: 15/Noviembre/2025, ISBN: 9786075269481, Inventario: 25 ejemplares

# %% [markdown]
# ---- Práctica con código XML música ----

# %%
# Create a dummy XML file for demonstration
xml_data = '''

 <Musica>
    <Genero>
        <Nombre>Jazz, soul-jazz, blues / RyB</Nombre>
        <Artista>Nina Simone</Artista>
        <Ano>1965 (1 de octubre de 1965)</Ano>
        <Album>Pastel Blues</Album>
        <Duracion>35:02 minutos</Duracion>
        <Canciones>9 pistas</Canciones>
     </Genero>

     <Genero>
        <Nombre>Jazz, soul-jazz, blues / RyB</Nombre>
        <Artista>Billie Holiday</Artista>
        <Ano>1958</Ano>
        <Album>Lady in Satin</Album>
        <Duracion>41:00 minutos</Duracion>
        <Canciones>12 pistas, versión original</Canciones>
    </Genero>

    <Genero>
        <Nombre>Gothic metal / rock sinfónico</Nombre>
        <Artista>Lacrimosa</Artista>
        <Ano>1999</Ano>
        <Album>Elodia</Album>
        <Duracion>57:57 minutos</Duracion>
        <Canciones>8 pistas</Canciones>
    </Genero>
 </Musica>
'''

#'w' es para sólo lectura

with open('Musica.xml', 'w') as f:
    f.write(xml_data)

print("Dummy 'Musica.xml' created successfully.")

# Parse the XML file abrir y recorder un archivo
tree = ET.parse('Musica.xml')
root = tree.getroot()

# Iterate and print libro data
print("\nGenero DataBase")
for Genero in root.findall("Genero"): #desde la raíz encuentra cada hijo
    Nombre = Genero.find("Nombre").text
    Artista = Genero.find("Artista").text
    Ano = Genero.find("Ano").text
    Album = Genero.find("Album").text
    Duracion = Genero.find("Duracion").text
    Canciones = Genero.find("Canciones").text
    print(f"Artista: {Artista}, Ano: {Ano}, Album: {Album}, Duracion: {Duracion}, Canciones: {Canciones}")
# Out:
# Dummy 'Musica.xml' created successfully.
#
# Genero DataBase
# Artista: Nina Simone, Ano: 1965 (1 de octubre de 1965), Album: Pastel Blues, Duracion: 35:02 minutos, Canciones: 9 pistas
# Artista: Billie Holiday, Ano: 1958, Album: Lady in Satin, Duracion: 41:00 minutos, Canciones: 12 pistas, versión original
# Artista: Lacrimosa, Ano: 1999, Album: Elodia, Duracion: 57:57 minutos, Canciones: 8 pistas
